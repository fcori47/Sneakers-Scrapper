# %%
import pandas as pd
import numpy as np

df = pd.read_excel('zapatillas_running_definitivo.xlsx')
df
# Out:
#                             Modelo    Marca  \
# 0              Nike Downshifter 11     Nike
# 1              adidas 4d Fwd Pulse   adidas
# 2                     Nike Quest 4     Nike
# 3    Medias Asics 1/2 Caña Graphic    Asics
# 4               Nike Juniper Trail     Nike
# ..                             ...      ...
# 867                Salomon Hypulse  Salomon
# 868           Nike Pegasus Trail 3     Nike
# 869  Medias Nike Spark Lightweight     Nike
# 870        Nike Air Max Infinity 2     Nike
# 871           Reebok Lite Plus 3.0   Reebok
#
#                                            Promociones  Precio  \
# 0    6/8 Sin interes (Naranja X), 3 Sin interes (Nike)   16999
# 1    6/8 Sin interes (Naranja X), 3 Sin interes (Nike)   34999
# 2    6/8 Sin interes (Naranja X), 3 Sin interes (Nike)   21599
# 3    6/8 Sin interes (Naranja X), 3 Sin interes (Nike)    1199
# 4    6/8 Sin interes (Naranja X), 3 Sin interes (Nike)   23099
# ...

# %%
talles = [35,36,37,38,39,40,41,42]

ws = {'Modelo': df['Modelo'], 'Marca': df['Marca'], 'Talle': np.random.choice(talles, size=len(r)), 'Color': df['Color'], 'Cantidad': np.random.randint(30, size=len(r))  ,'Precio': df['Precio'], 'Precio 8 Cuotas': df['Precio 8 Cuotas'], 'Precio 6 Cuotas': df['Precio 6 Cuotas'], 'Precio 3 Cuotas': df['Precio 3 Cuotas'],'Disponible en': df['Disponible en']   }
r = pd.DataFrame(ws)
r
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11724/415570044.py in <module>
#       2
#       3 ws = {'Modelo': df['Modelo'], 'Marca': df['Marca'], 'Talle': np.random.choice(talles, size=len(r)), 'Color': df['Color'], 'Cantidad': np.random.randint(30, size=len(r))  ,'Precio': df['Precio'], 'Precio 8 Cuotas': df['Precio 8 Cuotas'], 'Precio 6 Cuotas': df['Precio 6 Cuotas'], 'Precio 3 Cuotas': df['Precio 3 Cuotas'],'Disponible en': df['Disponible en']   }
# ----> 4 r = pd.DataFrame(ws)
#       5 r
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
# ...

# %%
r = r[r['Modelo'].str.contains('Calza') ==False]
r = r[r['Modelo'].str.contains('Short')==False]
r = r[r['Modelo'].str.contains('Medias')==False]
r['Categoria'] = 'Running'
r
# Out:
#                        Modelo    Marca  Talle     Color  Cantidad  Precio  \
# 0         Nike Downshifter 11     Nike     41  Amarillo        15   16999
# 1         adidas 4d Fwd Pulse   adidas     38     Verde        15   34999
# 2                Nike Quest 4     Nike     36     Negro         4   21599
# 4          Nike Juniper Trail     Nike     41     Verde        28   23099
# 5              adidas Run 70S   adidas     36   Violeta        14   17899
# ..                        ...      ...    ...       ...       ...     ...
# 866     adidas Lite Racer 2.0   adidas     35      Azul        26   15799
# 867           Salomon Hypulse  Salomon     36   Violeta         1   29399
# 868      Nike Pegasus Trail 3     Nike     38     Verde        29   32499
# 870   Nike Air Max Infinity 2     Nike     41      Azul        20   24999
# 871      Reebok Lite Plus 3.0   Reebok     35      Rojo        22   11999
#
#      Precio 8 Cuotas  Precio 6 Cuotas  Precio 3 Cuotas  \
# ...

# %%
r.to_excel('categoria_running.xlsx')

# %%
calzas = df[df['Modelo'].str.contains('Calza')]
calzas
# Out:
#                                              Modelo         Marca  \
# 38                             Calza Nike Epic Fast          Nike
# 51                    Calza Nike Dri-FIT Swoosh Run          Nike
# 80                         Calza adidas Own The Run        adidas
# 120  Calza Puma Run Marathon High Waist Full Length          Puma
# 139       Calza Nike Dri-Fit Run Division Epic Fast          Nike
# 161          Calza Puma 7/8 Regular Rise Run Launch          Puma
# 222                          Calza Nike Air Dri-FIT          Nike
# 262                            Calzas Fila Performa          Fila
# 265                   Calza adidas Saturday 1/2 Tgt        adidas
# 279                  Calza adidas Fastimpact Bike T        adidas
# 282            Calza Puma Run Hight Waist Shine 7/8          Puma
# 307                       Calza Asics 7/8 Essential         Asics
# 314            Calza Puma Studio Rib High Waist 7/8          Puma
# ...

# %%
shorts = df[df['Modelo'].str.contains('Short')]
shorts
# Out:
#                                         Modelo         Marca  \
# 77                        Short Lotto Speed IX         Lotto
# 113                       Short Nike Aeroswift          Nike
# 128                      Short Nike Challenger          Nike
# 131      Remera Puma Run Favorite Short Sleeve          Puma
# 140            Short Puma Run Favorite Woven 7          Puma
# ..                                         ...           ...
# 823                      Short Nike Swoosh Run          Nike
# 833          Short Puma Train Evoknit + 5 2In1          Puma
# 835  Remera Under Armour Streaker Short Sleeve  Under Armour
# 838           Short Under Armour Launch SW 7''  Under Armour
# 848            Short Nike Flex Stride Wild Run          Nike
#
#                                            Promociones  Precio  \
# 77   6/8 Sin interes (Naranja X), 3 Sin interes (Nike)    3999
# 113  6/8 Sin interes (Naranja X), 3 Sin interes (Nike)    9999
# ...

# %%
medias = df[df['Modelo'].str.contains('Medias')]
medias
# Out:
#                                  Modelo  Marca  \
# 3         Medias Asics 1/2 Caña Graphic  Asics
# 36                    Medias Lotto Flow  Lotto
# 112         Pack de Medias Lotto Run x2  Lotto
# 152         Pack de Medias Lotto Run x2  Lotto
# 154        Pack De Medias Asics Tech x3  Asics
# 230       Medias Nike Spark Lightweight   Nike
# 246                   Medias Lotto Flow  Lotto
# 367                   Medias Nike Elite   Nike
# 434  Pack de Medias Asics 1/2 Caña Icon  Asics
# 446  Pack de Medias Fila Bio Running x3   Fila
# 453                Medias Lotto Classic  Lotto
# 455        Pack de Medias Asics Tech x3  Asics
# 457  Pack de Medias Fila Bio Running x3   Fila
# 462                   Medias Lotto Flow  Lotto
# 469  Pack de Medias Fila Bio Running x3   Fila
# 727       Medias Nike Spark Lightweight   Nike
# 729                   Medias Nike Spark   Nike
# 748                   Medias Nike Spark   Nike
# 749     Medias Nike Elite Over-The-Calf   Nike
# ...
