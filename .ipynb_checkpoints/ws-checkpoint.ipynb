# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_excel('categoria_running.xlsx')
df1.drop('Unnamed: 0', axis=1, inplace=True)
df1
# Out:
#                        Modelo    Marca  Talle     Color  Cantidad  Precio  \
# 0         Nike Downshifter 11     Nike     41  Amarillo        15   16999
# 1         adidas 4d Fwd Pulse   adidas     38     Verde        15   34999
# 2                Nike Quest 4     Nike     36     Negro         4   21599
# 3          Nike Juniper Trail     Nike     41     Verde        28   23099
# 4              adidas Run 70S   adidas     36   Violeta        14   17899
# ..                        ...      ...    ...       ...       ...     ...
# 704     adidas Lite Racer 2.0   adidas     35      Azul        26   15799
# 705           Salomon Hypulse  Salomon     36   Violeta         1   29399
# 706      Nike Pegasus Trail 3     Nike     38     Verde        29   32499
# 707   Nike Air Max Infinity 2     Nike     41      Azul        20   24999
# 708      Reebok Lite Plus 3.0   Reebok     35      Rojo        22   11999
#
#      Precio 8 Cuotas  Precio 6 Cuotas  Precio 3 Cuotas  \
# ...

# %%
df2 = pd.read_excel('categoria_moda.xlsx')
df2.drop('Unnamed: 0', axis=1, inplace=True)
df2
# Out:
#                                        Modelo     Marca  Talle     Color  \
# 0                            Topper Nikita Cs    Topper     41     Verde
# 1                               Puma Karmen L      Puma     41  Amarillo
# 2                              Puma Rose Plus      Puma     37      Azul
# 3                     Puma R78 Voyage Premium      Puma     37   Violeta
# 4                      Lotto Runner Sue Basic     Lotto     41     Negro
# ..                                        ...       ...    ...       ...
# 345                  Nike Court Legacy Canvas      Nike     36      Azul
# 346                         Fila Float Jogger      Fila     38  Amarillo
# 347   Converse Chuck Taylor All Star Linen Ox  Converse     35   Violeta
# 348                             Lotto Trainer     Lotto     40     Verde
# 349                        Nike Air Max Excee      Nike     35  Amarillo
#
#      Cantidad  Precio  Precio 8 Cuotas  Precio 6 Cuotas  Precio 3 Cuotas  \
# ...

# %%
df3 = pd.read_excel('categoria_training.xlsx')
df3.drop('Unnamed: 0', axis=1, inplace=True)
df3
# Out:
#                          Modelo   Marca  Talle     Color  Cantidad  Precio  \
# 0        Topper Strong Pace III  Topper     36      Azul        22   11799
# 1        Topper Strong Pace III  Topper     39  Amarillo        28   11799
# 2                Fila Trend 2.0    Fila     38      Rosa         5   13699
# 3     Topper Ultralight II Mesh  Topper     42      Rosa         2   10299
# 4                  Topper Squat  Topper     40     Verde        14   14399
# ..                          ...     ...    ...       ...       ...     ...
# 102     Nike Air Max Bella Tr 3    Nike     39     Verde        21   20599
# 103    Nike Air Zoom SuperRep 2    Nike     39      Azul        21   31699
# 104         Puma Lvl-Up Xt Wn S    Puma     37  Amarillo         1   19999
# 105          Nike Free Metcon 4    Nike     35      Azul        14   36699
# 106             Topper Vr Speed  Topper     36     Negro         8    8999
#
#      Precio 8 Cuotas  Precio 6 Cuotas  Precio 3 Cuotas  \
# ...

# %%
frames = [df1,df2,df3]
df = pd.concat(frames)
df
# Out:
#                         Modelo   Marca  Talle     Color  Cantidad  Precio  \
# 0          Nike Downshifter 11    Nike     41  Amarillo        15   16999
# 1          adidas 4d Fwd Pulse  adidas     38     Verde        15   34999
# 2                 Nike Quest 4    Nike     36     Negro         4   21599
# 3           Nike Juniper Trail    Nike     41     Verde        28   23099
# 4               adidas Run 70S  adidas     36   Violeta        14   17899
# ..                         ...     ...    ...       ...       ...     ...
# 102    Nike Air Max Bella Tr 3    Nike     39     Verde        21   20599
# 103   Nike Air Zoom SuperRep 2    Nike     39      Azul        21   31699
# 104        Puma Lvl-Up Xt Wn S    Puma     37  Amarillo         1   19999
# 105         Nike Free Metcon 4    Nike     35      Azul        14   36699
# 106            Topper Vr Speed  Topper     36     Negro         8    8999
#
#      Precio 8 Cuotas  Precio 6 Cuotas  Precio 3 Cuotas  \
# ...

# %%
df.to_excel('zapatillas.xlsx')
